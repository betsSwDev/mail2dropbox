# %% [markdown]
# ### REPARTITION DES BONS DE LIVRAISON PAR FOURNISSEUR

# %%
import os
import shutil
import pdfplumber
import logging

# === Réduction des messages parasites ===
logging.getLogger("pdfminer").setLevel(logging.ERROR)


# Répertoire contenant les fichiers PDF à analyser
repertoire_source = "C:/Users/Mr AI/Desktop/Lieferung_2025"

# Répertoires de destination
Lieferung_ALURIT = os.path.join(repertoire_source, "Lieferung ALURIT")
Lieferung_BENZ = os.path.join(repertoire_source, "Lieferung BENZ")
Lieferung_Würth = os.path.join(repertoire_source, "Lieferung Würth")
Lieferung_ADKO = os.path.join(repertoire_source, "Lieferung ADKO")
Lieferung_BTI_BEFESTIGUNGSTECHNIK = os.path.join(repertoire_source, "Lieferung BTI_BEFESTIGUNGSTECHNIK")
Lieferung_FISCHER = os.path.join(repertoire_source, "Lieferung FISCHER")
Lieferung_FARBTEX = os.path.join(repertoire_source, "Lieferung FARBTEX")
Lieferung_Holz_Hauff_GmbH = os.path.join(repertoire_source, "Lieferung Holz_Hauff_GmbH")
Lieferung_KURZ = os.path.join(repertoire_source, "Lieferung KURZ")
Lieferung_schrade = os.path.join(repertoire_source, "Lieferung schrade")
Lieferung_sto = os.path.join(repertoire_source, "Lieferung Sto")
Autres = os.path.join(repertoire_source, "Lieferung Autres")


# Crée les dossiers s'ils n'existent pas
os.makedirs(Lieferung_ALURIT, exist_ok=True)
os.makedirs(Lieferung_BENZ, exist_ok=True)
os.makedirs(Lieferung_Würth, exist_ok=True)
os.makedirs(Lieferung_ADKO, exist_ok=True)
os.makedirs(Lieferung_BTI_BEFESTIGUNGSTECHNIK, exist_ok=True)
os.makedirs(Lieferung_FISCHER, exist_ok=True)
os.makedirs(Lieferung_FARBTEX, exist_ok=True)
os.makedirs(Lieferung_Holz_Hauff_GmbH, exist_ok=True)
os.makedirs(Lieferung_KURZ, exist_ok=True)
os.makedirs(Lieferung_schrade, exist_ok=True)
os.makedirs(Lieferung_sto, exist_ok=True)
os.makedirs(Autres, exist_ok=True)


# Parcours des fichiers dans le dossier source
for fichier in os.listdir(repertoire_source):
    if fichier.lower().endswith(".pdf"):
        chemin_pdf = os.path.join(repertoire_source, fichier)

        try:
            with pdfplumber.open(chemin_pdf) as pdf:
                texte_complet = ""
                for page in pdf.pages:
                    texte_complet += page.extract_text() or ""
                pdf.close()  # fermeture explicite ici
                if "ALURIT" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_ALURIT, fichier))
                    print(f"✅ Déplacé vers ALURIT : {fichier}")
                elif "ADKO GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_ADKO, fichier))
                    print(f"✅ Déplacé vers ADKO : {fichier}")
                elif "BENZ GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_BENZ, fichier))
                    print(f"✅ Déplacé vers BENZ GmbH : {fichier}")
                elif "Würth GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_Würth, fichier))
                    print(f"✅ Déplacé vers Würth GmbH : {fichier}")
                elif "BTI Befestigungstechnik" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_BTI_BEFESTIGUNGSTECHNIK, fichier))
                    print(f"✅ Déplacé vers BTI BEFESTIGUNGSTECHNIK : {fichier}")
                elif "Fischer - J. W. Zander GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_FISCHER, fichier))
                    print(f"✅ Déplacé vers FISCHER : {fichier}")
                elif "FARBTEX" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_FARBTEX, fichier))
                    print(f"✅ Déplacé vers FARBTEX : {fichier}")
                elif "Holz-Hauff GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_Holz_Hauff_GmbH, fichier))
                    print(f"✅ Déplacé vers Holz-Hauff GmbH : {fichier}")
                elif "KURZ" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_KURZ, fichier))
                    print(f"✅ Déplacé vers KURZ : {fichier}")
                elif "Schrade GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_schrade, fichier))
                    print(f"✅ Déplacé vers schrade : {fichier}")
                elif "Sto SE" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Lieferung_sto, fichier))
                    print(f"✅ Déplacé vers Sto : {fichier}")
                else:
                    shutil.move(chemin_pdf, os.path.join(Autres, fichier))
                    print(f"📁 Déplacé vers Autres : {fichier}")

        except Exception as e:
            print(f"❌ Erreur avec {fichier} : {e}")
# Out:
# ✅ Déplacé vers BENZ GmbH : 2025-01-23_1515_Lieferung_0801790239_Lieferung 0801790239.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-24_0715_Lieferung_0801790346_Lieferung 0801790346.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-24_1250_Lieferung_0801790832_Lieferung 0801790832.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-27_0719_Lieferung_0801791253_Lieferung 0801791253.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-27_0720_Lieferung_0801791260_Lieferung 0801791260.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-27_0855_Lieferung_0801791436_Lieferung 0801791436.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-27_0902_Lieferung_0801791444_Lieferung 0801791444.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-27_1418_Lieferung_0801791906_Lieferung 0801791906.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-29_0826_Lieferung_0801793046_Lieferung 0801793046.PDF
# ✅ Déplacé vers BENZ GmbH : 2025-01-29_1144_Lieferung_0801793384_Lieferung 0801793384.PDF
# ...

# %% [markdown]
# ### REPARTITION DES FACTURES PAR FOURNISSEURS

# %%
import os
import shutil
import pdfplumber
import logging

# === Réduction des messages parasites ===
logging.getLogger("pdfminer").setLevel(logging.ERROR)


# Répertoire contenant les fichiers PDF à analyser
repertoire_source = "C:/Users/Mr AI/Desktop/Rechnung_2025"

# Répertoires de destination
Rechnung_ALURIT = os.path.join(repertoire_source, "Rechnung ALURIT")
Rechnung_BENZ = os.path.join(repertoire_source, "Rechnung BENZ")
Rechnung_Würth = os.path.join(repertoire_source, "Rechnung Würth")
Rechnung_ADKO = os.path.join(repertoire_source, "Rechnung ADKO")
Rechnung_BTI_BEFESTIGUNGSTECHNIK = os.path.join(repertoire_source, "Rechnung BTI_BEFESTIGUNGSTECHNIK")
Rechnung_FISCHER = os.path.join(repertoire_source, "Rechnung FISCHER")
Rechnung_FARBTEX = os.path.join(repertoire_source, "Rechnung FARBTEX")
Rechnung_Holz_Hauff_GmbH = os.path.join(repertoire_source, "Rechnung Holz_Hauff_GmbH")
Rechnung_KURZ = os.path.join(repertoire_source, "Rechnung KURZ")
Rechnung_schrade = os.path.join(repertoire_source, "Rechnung schrade")
Rechnung_sto = os.path.join(repertoire_source, "Rechnung Sto")
Autres = os.path.join(repertoire_source, "Rechnung Autres")


# Crée les dossiers s'ils n'existent pas
os.makedirs(Rechnung_ALURIT, exist_ok=True)
os.makedirs(Rechnung_BENZ, exist_ok=True)
os.makedirs(Rechnung_Würth, exist_ok=True)
os.makedirs(Rechnung_ADKO, exist_ok=True)
os.makedirs(Rechnung_BTI_BEFESTIGUNGSTECHNIK, exist_ok=True)
os.makedirs(Rechnung_FISCHER, exist_ok=True)
os.makedirs(Rechnung_FARBTEX, exist_ok=True)
os.makedirs(Rechnung_Holz_Hauff_GmbH, exist_ok=True)
os.makedirs(Rechnung_KURZ, exist_ok=True)
os.makedirs(Rechnung_schrade, exist_ok=True)
os.makedirs(Rechnung_sto, exist_ok=True)
os.makedirs(Autres, exist_ok=True)


# Parcours des fichiers dans le dossier source
for fichier in os.listdir(repertoire_source):
    if fichier.lower().endswith(".pdf"):
        chemin_pdf = os.path.join(repertoire_source, fichier)

        try:
            with pdfplumber.open(chemin_pdf) as pdf:
                texte_complet = ""
                for page in pdf.pages:
                    texte_complet += page.extract_text() or ""
                pdf.close()  # fermeture explicite ici
                if "ALURIT" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_ALURIT, fichier))
                    print(f"✅ Déplacé vers ALURIT : {fichier}")
                elif "ADKO GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_ADKO, fichier))
                    print(f"✅ Déplacé vers ADKO : {fichier}")
                elif "BENZ GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_BENZ, fichier))
                    print(f"✅ Déplacé vers BENZ GmbH : {fichier}")
                elif "Würth GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_Würth, fichier))
                    print(f"✅ Déplacé vers Würth GmbH : {fichier}")
                elif "BTI Befestigungstechnik" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_BTI_BEFESTIGUNGSTECHNIK, fichier))
                    print(f"✅ Déplacé vers BTI BEFESTIGUNGSTECHNIK : {fichier}")
                elif "Fischer - J. W. Zander GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_FISCHER, fichier))
                    print(f"✅ Déplacé vers FISCHER : {fichier}")
                elif "FARBTEX" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_FARBTEX, fichier))
                    print(f"✅ Déplacé vers FARBTEX : {fichier}")
                elif "Holz-Hauff GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_Holz_Hauff_GmbH, fichier))
                    print(f"✅ Déplacé vers Holz-Hauff GmbH : {fichier}")
                elif "KURZ" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_KURZ, fichier))
                    print(f"✅ Déplacé vers KURZ : {fichier}")
                elif "Schrade GmbH" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_schrade, fichier))
                    print(f"✅ Déplacé vers schrade : {fichier}")
                elif "Sto SE" in texte_complet:
                    shutil.move(chemin_pdf, os.path.join(Rechnung_sto, fichier))
                    print(f"✅ Déplacé vers sto : {fichier}")
                else:
                    shutil.move(chemin_pdf, os.path.join(Autres, fichier))
                    print(f"📁 Déplacé vers Autres : {fichier}")

        except Exception as e: 
            print(f"❌ Erreur avec {fichier} : {e}")
# Out:
# ✅ Déplacé vers BENZ GmbH : 2025-01-02_0702_Rechnung_0091781407_Rechnung 0091781407.PDF
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555108_Belege_2555108.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555108_Newsletter_d5fddef5-6e60-4510-aa7c-0679a96987e2.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555108_Rechnung_2555108.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555109_Newsletter_d5fddef5-6e60-4510-aa7c-0679a96987e2.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555109_Rechnung_2555109.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555110_Newsletter_d5fddef5-6e60-4510-aa7c-0679a96987e2.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555110_Rechnung_2555110.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555111_Newsletter_d5fddef5-6e60-4510-aa7c-0679a96987e2.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555111_Rechnung_2555111.pdf
# ✅ Déplacé vers KURZ : 2025-01-07_1040_Rechnung_2555112_Belege_2555112.pdf
# ...

# %% [markdown]
# ### MISE DES LIEFERUNG Et DES RECHNUNG EN COMMUN DANS UN DOSSIER SPECIFIQUE

# %%
import os
import shutil

# Dossiers sources
source1 = "C:/Users/Mr AI/Desktop/Lieferung_2025"
source2 = "C:/Users/Mr AI/Desktop/Rechnung_2025"

# Dossier où tu veux mettre les résultats regroupés
destination_root = "C:/Users/Mr AI/Desktop/Full"

# Liste de tous les dossiers à analyser
all_dirs = []

for base in [source1, source2]:
    for name in os.listdir(base):
        full_path = os.path.join(base, name)
        if os.path.isdir(full_path):
            all_dirs.append((name, full_path))

# Fonction pour extraire le mot-clé commun (ici on prend le dernier mot du nom du dossier)
def extract_key(name):
    return name.split()[-1].strip()

# Grouper les chemins par mot-clé
grouped = {}
for name, path in all_dirs:
    key = extract_key(name)
    grouped.setdefault(key, []).append((name, path))

# Déplacer les dossiers vers leur dossier regroupé
for key, folders in grouped.items():
    if len(folders) < 2:
        continue  # Ne regrouper que les clés présentes dans au moins 2 dossiers

    key_dest = os.path.join(destination_root, key)
    os.makedirs(key_dest, exist_ok=True)

    print(f"\nCréation du dossier : {key_dest}")
    for original_name, original_path in folders:
        new_path = os.path.join(key_dest, original_name)
        print(f"Déplacement de '{original_name}' vers '{new_path}'")
        shutil.move(original_path, new_path)

print("\nRegroupement terminé.")
# Out:
# Création du dossier : C:/Users/Mr AI/Desktop/Full\ADKO
# Déplacement de 'Lieferung ADKO' vers 'C:/Users/Mr AI/Desktop/Full\ADKO\Lieferung ADKO'
# Déplacement de 'Rechnung ADKO' vers 'C:/Users/Mr AI/Desktop/Full\ADKO\Rechnung ADKO'
#
# Création du dossier : C:/Users/Mr AI/Desktop/Full\ALURIT
# Déplacement de 'Lieferung ALURIT' vers 'C:/Users/Mr AI/Desktop/Full\ALURIT\Lieferung ALURIT'
# Déplacement de 'Rechnung ALURIT' vers 'C:/Users/Mr AI/Desktop/Full\ALURIT\Rechnung ALURIT'
#
# Création du dossier : C:/Users/Mr AI/Desktop/Full\Autres
# Déplacement de 'Lieferung Autres' vers 'C:/Users/Mr AI/Desktop/Full\Autres\Lieferung Autres'
# Déplacement de 'Rechnung Autres' vers 'C:/Users/Mr AI/Desktop/Full\Autres\Rechnung Autres'
#
# Création du dossier : C:/Users/Mr AI/Desktop/Full\BENZ
# Déplacement de 'Lieferung BENZ' vers 'C:/Users/Mr AI/Desktop/Full\BENZ\Lieferung BENZ'
# Déplacement de 'Rechnung BENZ' vers 'C:/Users/Mr AI/Desktop/Full\BENZ\Rechnung BENZ'
#
# ...

# %% [markdown]
# # LIAISON DES BONS DE LIVRAISONS ET DES FACTURES

# %% [markdown]
# ### CAS DE BENZ

# %%
import os
import shutil
import pdfplumber
import logging

# === Réduction des messages parasites ===
logging.getLogger("pdfminer").setLevel(logging.ERROR)

# === Fonctions Utilitaires ===

def clean_value(value):
    return ''.join(filter(str.isdigit, value)) if value else ""

def extract_data(text, keyword):
    for line in text.split('\n'):
        if keyword in line:
            parts = line.split()
            for i, part in enumerate(parts):
                if keyword in part and i + 1 < len(parts):
                    return parts[i + 1]
    return ""

def extract_lieferschein_from_text(text):
    return clean_value(extract_data(text, "Lieferschein")) if "Lieferschein" in text else ""

def extract_belegnummer_from_text(text):
    return clean_value(extract_data(text, "Beleg-Nr.")) if "Beleg-Nr." in text else ""

def extract_belegdatum_from_text(text):
    for line in text.split('\n'):
        if "Belegdatum" in line:
            parts = line.strip().split()
            for part in parts:
                if part.count('.') == 2:
                    return part.replace('.', '-')  # Format AAAA-MM-JJ
    return ""

def extract_lieferdatum_from_text(text):
    for line in text.split('\n'):
        if "Lieferdatum" in line:
            parts = line.strip().split()
            for part in parts:
                if part.count('.') == 2:
                    return part.replace('.', '-')
    return ""

# === Chemins ===

lieferschein_folder = r"C:/Users/Mr AI/Desktop/Full/BENZ/Lieferung BENZ"
rechnung_folder = r"C:/Users/Mr AI/Desktop/Full/BENZ/Rechnung BENZ"
matched_folder = r"C:/Users/Mr AI/Desktop/Full/BENZ/matched"
unmatched_folder = r"C:/Users/Mr AI/Desktop/Full/BENZ/unmatched"

os.makedirs(os.path.join(unmatched_folder, "Lieferschein"), exist_ok=True)
os.makedirs(os.path.join(unmatched_folder, "Rechnung"), exist_ok=True)
os.makedirs(matched_folder, exist_ok=True)

# === Extraction des fichiers avec leurs valeurs associées ===

lieferschein_map = {}  # {belegnummer: (chemin, belegdatum)}
for f in os.listdir(lieferschein_folder):
    if f.lower().endswith(".pdf"):
        path = os.path.join(lieferschein_folder, f)
        with pdfplumber.open(path) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                if text:
                    belegnummer = extract_belegnummer_from_text(text)
                    belegdatum = extract_belegdatum_from_text(text)
                    if belegnummer:
                        lieferschein_map[belegnummer] = (path, belegdatum)
                        break

rechnung_map = {}  # {lieferschein_num: (chemin, lieferdatum)}
for f in os.listdir(rechnung_folder):
    if f.lower().endswith(".pdf"):
        path = os.path.join(rechnung_folder, f)
        with pdfplumber.open(path) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                if text:
                    lieferschein_num = extract_lieferschein_from_text(text)
                    lieferdatum = extract_lieferdatum_from_text(text)
                    if lieferschein_num:
                        rechnung_map[lieferschein_num] = (path, lieferdatum)
                        break

# === Comparaison et tri ===

matched_keys = set(lieferschein_map.keys()) & set(rechnung_map.keys())

# Fichiers appariés
for key in matched_keys:
    lieferschein_path, belegdatum = lieferschein_map[key]
    rechnung_path, _ = rechnung_map[key]

    dir_name = f"{key}_{belegdatum}" if belegdatum else key
    match_dir = os.path.join(matched_folder, dir_name)

    os.makedirs(os.path.join(match_dir, "Lieferschein"), exist_ok=True)
    os.makedirs(os.path.join(match_dir, "Rechnung"), exist_ok=True)

    shutil.copy2(lieferschein_path, os.path.join(match_dir, "Lieferschein", os.path.basename(lieferschein_path)))
    shutil.copy2(rechnung_path, os.path.join(match_dir, "Rechnung", os.path.basename(rechnung_path)))

# Fichiers non appariés
for key, (path, _) in lieferschein_map.items():
    if key not in matched_keys:
        shutil.copy2(path, os.path.join(unmatched_folder, "Lieferschein", os.path.basename(path)))

for key, (path, _) in rechnung_map.items():
    if key not in matched_keys:
        shutil.copy2(path, os.path.join(unmatched_folder, "Rechnung", os.path.basename(path)))

print("Classement terminé.")
# Out:
# Classement terminé.

# %% [markdown]
# ### CAS DE WURTH

# %%
import sys
import shutil
import pdfplumber
import os
import re
import logging


# === Réduction des messages parasites ===
logging.getLogger("pdfminer").setLevel(logging.ERROR)

# === Fonctions Utilitaires ===

def clean_value(value):
    return ''.join(filter(str.isdigit, value)) if value else ""

def extract_data(text, keyword):
    for line in text.split('\n'):
        if keyword in line:
            parts = line.split()
            for i, part in enumerate(parts):
                if keyword in part and i + 1 < len(parts):
                    return parts[i + 1]
    return ""

def extract_auftrag_from_text(text):
    
    # Trouve tous les numéros à 7-12 chiffres après le mot "Auftrag"
    return re.findall(r"Auftrag[^0-9]{0,10}(\d{7,12})", text, re.IGNORECASE)

def extract_lieferschein_date_for_auftrag(text, auftrag):
    """
    Extrait la date de livraison (Lieferschein-Datum) pour un numéro d'Auftrag spécifique.
    On cherche un bloc de texte contenant à la fois l'Auftrag et une date.
    """
    # Exemple : Auftrag 2228255647 → chercher la ligne contenant ce numéro suivi d'une date au format JJ.MM.AAAA
    # Ici on prend des blocs qui contiennent l’Auftrag + une date proche
    pattern = rf"Auftrag[^0-9]{{0,10}}{auftrag}[^0-9]{{0,20}}.*?(\d{{2}}\.\d{{2}}\.\d{{4}})"
    match = re.search(pattern, text, re.IGNORECASE | re.DOTALL)
    return match.group(1) if match else "kein_datum"

# === Chemins ===

lieferung_folder = r"C:/Users/Mr AI/Desktop/Full/Würth/Lieferung Würth"
rechnung_folder = r"C:/Users/Mr AI/Desktop/Full/Würth/Rechnung Würth"
matched_folder = r"C:/Users/Mr AI/Desktop/Full/Würth/matched"
unmatched_folder = r"C:/Users/Mr AI/Desktop/Full/Würth/Unmatched"
os.makedirs(os.path.join(unmatched_folder, "Lieferschein"), exist_ok=True)
os.makedirs(os.path.join(unmatched_folder, "Rechnung"), exist_ok=True)
os.makedirs(matched_folder, exist_ok=True)

# === Extraction des fichiers avec leurs valeurs associées ===

lieferung_map = {}  # {valeur : chemin du fichier}
for f in os.listdir(lieferung_folder):
    if f.lower().endswith(".pdf"):
        path = os.path.join(lieferung_folder, f)
        with pdfplumber.open(path) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                if text:
                    val = extract_auftrag_from_text(text)
                    print(f"[LIEFERSCHEIN] Fichier: {f} → Auftrag extrait: '{val}'")

                    for auftrag in val:
                        lieferung_map[auftrag] = path
                        break

rechnung_map = {}  # {auftrag: [liste de chemins des fichiers rechnung]}
for f in os.listdir(rechnung_folder):
    if f.lower().endswith(".pdf"):
        path = os.path.join(rechnung_folder, f)
        with pdfplumber.open(path) as pdf:
            for page in pdf.pages:
                text = page.extract_text()
                if text:
                    auftrag_extrait = extract_auftrag_from_text(text)
                    print(f"[RECHNUNG] Fichier: {f} → Auftrag extraits: {auftrag_extrait}")
                    for auftrag in auftrag_extrait:
                        rechnung_map.setdefault(auftrag, []).append(path)
                    break

# === Comparaison et tri ===

matched_keys = set(lieferung_map.keys()) & set(rechnung_map.keys())

# Fichiers appariés
for key in matched_keys:
    # === Extraire les dates associées au bon Auftrag ===

    lieferschein_date = "kein_datum"

    # 📄 Extraire la date du fichier Lieferschein
    with pdfplumber.open(lieferung_map[key]) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                match = re.search(r"Lieferschein[-\s]?Datum[^0-9]{0,10}(\d{2}\.\d{2}\.\d{4})", text)
                if match:
                    lieferschein_date = match.group(1)
                break  # Première date trouvée suffit

    # 📁 Créer un nom de dossier enrichi avec la date du Lieferschein
    folder_name = f"{key}__Bon de livraison fait le_{lieferschein_date}"
    match_dir = os.path.join(matched_folder, folder_name)

    os.makedirs(os.path.join(match_dir, "Lieferschein"), exist_ok=True)
    os.makedirs(os.path.join(match_dir, "Rechnung"), exist_ok=True)
    
    shutil.copy2(lieferung_map[key], os.path.join(match_dir, "Lieferschein", os.path.basename(lieferung_map[key])))
    
    for rechnung_path in rechnung_map[key]:
        shutil.copy2(rechnung_path, os.path.join(match_dir, "Rechnung", os.path.basename(rechnung_path)))

# Fichiers non appariés
for key, path in lieferung_map.items():
    if key not in matched_keys:
        shutil.copy2(path, os.path.join(unmatched_folder, "Lieferschein", os.path.basename(path)))

used_files = {os.path.basename(p) for key in matched_keys for p in rechnung_map[key]}
for auftrag, paths in rechnung_map.items():
    if auftrag not in matched_keys:
        for path in paths:
            if os.path.basename(path) not in used_files:
                shutil.copy2(path, os.path.join(unmatched_folder, "Rechnung", os.path.basename(path)))

print("Classement terminé 😊 .")
# Out:
# [LIEFERSCHEIN] Fichier: 2025-01-31_1614_Würth_Ihr_digitaler_Lieferschein_für_Lieferung_8103778812_Würth_Lieferschein_8103778812.pdf → Auftrag extrait: '['2227555615']'
# [LIEFERSCHEIN] Fichier: 2025-01-31_1614_Würth_Ihr_digitaler_Lieferschein_für_Lieferung_8103778812_Würth_Lieferschein_8103778812.pdf → Auftrag extrait: '[]'
# [LIEFERSCHEIN] Fichier: 2025-02-06_1355_Würth_Ihr_digitaler_Lieferschein_für_Lieferung_8104350866_Würth_Lieferschein_8104350866.pdf → Auftrag extrait: '['2228022094']'
# [LIEFERSCHEIN] Fichier: 2025-02-06_1355_Würth_Ihr_digitaler_Lieferschein_für_Lieferung_8104350866_Würth_Lieferschein_8104350866.pdf → Auftrag extrait: '[]'
# [LIEFERSCHEIN] Fichier: 2025-02-06_1827_Würth_Ihr_digitaler_Lieferschein_für_Lieferung_8104396799_Würth_Lieferschein_8104396799.pdf → Auftrag extrait: '['2228065043']'
# [LIEFERSCHEIN] Fichier: 2025-02-06_1827_Würth_Ihr_digitaler_Lieferschein_für_Lieferung_8104396799_Würth_Lieferschein_8104396799.pdf → Auftrag extrait: '[]'
# ...
